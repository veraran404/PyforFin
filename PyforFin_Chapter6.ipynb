# %%
from ImportAll import *
from Functions import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Chapter 6. Financial Time Series

# %%
df = pd.DataFrame([10, 20, 30, 40], columns=['numbers'],index=['a', 'b', 'c', 'd'])
df
# Out:
#    numbers
# a       10
# b       20
# c       30
# d       40

# %%
df.loc['c']
# Out:
# numbers    30
# Name: c, dtype: int64

# %%
df.loc[['a','c']]
# Out:
#    numbers
# a       10
# c       30

# %%
df.sum()
# Out:
# numbers    100
# dtype: int64

# %%
df.apply(lambda x:x**2)
# Out:
#    numbers
# a      100
# b      400
# c      900
# d     1600

# %%
df**2
# Out:
#    numbers
# a      100
# b      400
# c      900
# d     1600

# %%
df['floats'] = (1.5, 2.5, 3.5, 4.5);
df
# Out:
#    numbers  floats
# a       10     1.5
# b       20     2.5
# c       30     3.5
# d       40     4.5

# %%
df['names'] = pd.DataFrame(['Yves', 'Guido', 'Felix', 'Francesc'],
index=['d', 'a', 'b', 'c']);
df
# Out:
#    numbers  floats     names
# a       10     1.5     Guido
# b       20     2.5     Felix
# c       30     3.5  Francesc
# d       40     4.5      Yves

# %%
df.append({'numbers': 100, 'floats': 5.75, 'names': 'Henry'},
ignore_index=True)
# Out:
#    numbers  floats     names
# 0       10    1.50     Guido
# 1       20    2.50     Felix
# 2       30    3.50  Francesc
# 3       40    4.50      Yves
# 4      100    5.75     Henry

# %%
df = df.append(pd.DataFrame({'numbers': 100, 'floats': 5.75,
'names': 'Henry'}, index=['z',]));
df
# Out:
#    numbers  floats     names
# a       10    1.50     Guido
# b       20    2.50     Felix
# c       30    3.50  Francesc
# d       40    4.50      Yves
# z      100    5.75     Henry

# %%
df.join(pd.DataFrame([1, 4, 9, 16, 25],
index=['a', 'b', 'c', 'd', 'y'],
columns=['squares',]))
# Out:
#    numbers  floats     names  squares
# a       10    1.50     Guido      1.0
# b       20    2.50     Felix      4.0
# c       30    3.50  Francesc      9.0
# d       40    4.50      Yves     16.0
# z      100    5.75     Henry      NaN

# %%
df = df.join(pd.DataFrame([1, 4, 9, 16, 25],
index=['a', 'b', 'c', 'd', 'y'],
columns=['squares',]),
how='outer');
df
# Out:
#    numbers  floats     names  squares
# a     10.0    1.50     Guido      1.0
# b     20.0    2.50     Felix      4.0
# c     30.0    3.50  Francesc      9.0
# d     40.0    4.50      Yves     16.0
# y      NaN     NaN       NaN     25.0
# z    100.0    5.75     Henry      NaN

# %%
df[['numbers', 'squares']].mean()
# column-wise mean
# Out:
# numbers    40.0
# squares    11.0
# dtype: float64

# %%
df[['numbers', 'squares']].std()
# column-wise standard deviation
# Out:
# numbers    35.355339
# squares     9.669540
# dtype: float64

# %%
a=np.random.standard_normal((9,4));#9行4列
a
# Out:
# array([[ 0.84766964,  0.02205611, -0.20751038, -0.05115727],
#        [-0.09555362, -2.21582308,  1.52695701,  0.10958818],
#        [ 1.15952697, -0.4051298 ,  1.1926763 ,  1.03918256],
#        [-0.47455549,  0.49888457, -0.20343333, -1.18150404],
#        [-0.43455856,  1.20964476, -0.18811219, -0.12668595],
#        [ 0.17422629, -0.06366783, -0.44334792,  0.37963393],
#        [ 0.84578291,  0.43011162,  0.08627599,  1.19450819],
#        [-1.95232189, -0.42971028,  0.55830613, -0.67998369],
#        [ 0.01952074,  1.55828699, -0.21667002,  2.10373069]])

# %%
df=pd.DataFrame(a);
df
# Out:
#           0         1         2         3
# 0  0.847670  0.022056 -0.207510 -0.051157
# 1 -0.095554 -2.215823  1.526957  0.109588
# 2  1.159527 -0.405130  1.192676  1.039183
# 3 -0.474555  0.498885 -0.203433 -1.181504
# 4 -0.434559  1.209645 -0.188112 -0.126686
# 5  0.174226 -0.063668 -0.443348  0.379634
# 6  0.845783  0.430112  0.086276  1.194508
# 7 -1.952322 -0.429710  0.558306 -0.679984
# 8  0.019521  1.558287 -0.216670  2.103731

# %%
df.columns = [['No1', 'No2', 'No3', 'No4']];
df
# Out:
#         No1       No2       No3       No4
# 0  0.847670  0.022056 -0.207510 -0.051157
# 1 -0.095554 -2.215823  1.526957  0.109588
# 2  1.159527 -0.405130  1.192676  1.039183
# 3 -0.474555  0.498885 -0.203433 -1.181504
# 4 -0.434559  1.209645 -0.188112 -0.126686
# 5  0.174226 -0.063668 -0.443348  0.379634
# 6  0.845783  0.430112  0.086276  1.194508
# 7 -1.952322 -0.429710  0.558306 -0.679984
# 8  0.019521  1.558287 -0.216670  2.103731

# %%
df.loc[3]['No2']
# Out:
# No2    0.498885
# Name: 3, dtype: float64

# %%
dates=pd.date_range('2015-1-1',periods=9,freq='M');
dates
# Out:
# DatetimeIndex(['2015-01-31', '2015-02-28', '2015-03-31', '2015-04-30',
#                '2015-05-31', '2015-06-30', '2015-07-31', '2015-08-31',
#                '2015-09-30'],
#               dtype='datetime64[ns]', freq='M')

# %%
df.index=dates;
df
# Out:
#                  No1       No2       No3       No4
# 2015-01-31  0.847670  0.022056 -0.207510 -0.051157
# 2015-02-28 -0.095554 -2.215823  1.526957  0.109588
# 2015-03-31  1.159527 -0.405130  1.192676  1.039183
# 2015-04-30 -0.474555  0.498885 -0.203433 -1.181504
# 2015-05-31 -0.434559  1.209645 -0.188112 -0.126686
# 2015-06-30  0.174226 -0.063668 -0.443348  0.379634
# 2015-07-31  0.845783  0.430112  0.086276  1.194508
# 2015-08-31 -1.952322 -0.429710  0.558306 -0.679984
# 2015-09-30  0.019521  1.558287 -0.216670  2.103731

# %%
np.array(df).round(6)
# Out:
# array([[ 0.84767 ,  0.022056, -0.20751 , -0.051157],
#        [-0.095554, -2.215823,  1.526957,  0.109588],
#        [ 1.159527, -0.40513 ,  1.192676,  1.039183],
#        [-0.474555,  0.498885, -0.203433, -1.181504],
#        [-0.434559,  1.209645, -0.188112, -0.126686],
#        [ 0.174226, -0.063668, -0.443348,  0.379634],
#        [ 0.845783,  0.430112,  0.086276,  1.194508],
#        [-1.952322, -0.42971 ,  0.558306, -0.679984],
#        [ 0.019521,  1.558287, -0.21667 ,  2.103731]])

# %%
df.cumsum()
# Out:
#                  No1       No2       No3       No4
# 2015-01-31  0.847670  0.022056 -0.207510 -0.051157
# 2015-02-28  0.752116 -2.193767  1.319447  0.058431
# 2015-03-31  1.911643 -2.598897  2.512123  1.097613
# 2015-04-30  1.437088 -2.100012  2.308690 -0.083891
# 2015-05-31  1.002529 -0.890367  2.120577 -0.210577
# 2015-06-30  1.176755 -0.954035  1.677229  0.169057
# 2015-07-31  2.022538 -0.523924  1.763505  1.363566
# 2015-08-31  0.070216 -0.953634  2.321812  0.683582
# 2015-09-30  0.089737  0.604653  2.105142  2.787313

# %%
df.describe()
# Out:
#             No1       No2       No3       No4
# count  9.000000  9.000000  9.000000  9.000000
# mean   0.009971  0.067184  0.233905  0.309701
# std    0.938281  1.092471  0.702154  1.006375
# min   -1.952322 -2.215823 -0.443348 -1.181504
# 25%   -0.434559 -0.405130 -0.207510 -0.126686
# 50%    0.019521  0.022056 -0.188112  0.109588
# 75%    0.845783  0.498885  0.558306  1.039183
# max    1.159527  1.558287  1.526957  2.103731

# %%
np.sqrt(df) #开方，负值为na
# Out:
# /Users/Xiran/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in sqrt
#   """Entry point for launching an IPython kernel.
#                  No1       No2       No3       No4
# 2015-01-31  0.920690  0.148513       NaN       NaN
# 2015-02-28       NaN       NaN  1.235701  0.331041
# 2015-03-31  1.076813       NaN  1.092097  1.019403
# 2015-04-30       NaN  0.706318       NaN       NaN
# 2015-05-31       NaN  1.099839       NaN       NaN
# 2015-06-30  0.417404       NaN       NaN  0.616144
# 2015-07-31  0.919665  0.655829  0.293728  1.092936
# 2015-08-31       NaN       NaN  0.747199       NaN
# 2015-09-30  0.139717  1.248314       NaN  1.450424

# %%
np.sqrt(df).sum()
# Out:
# /Users/Xiran/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in sqrt
#   """Entry point for launching an IPython kernel.
# No1    3.474289
# No2    3.858812
# No3    3.368725
# No4    4.509948
# dtype: float64

# %%
df.cumsum().plot(lw=2.0)
align_figures()
# Out:
# <img style="margin:0" align="left" src="...

# %%
import pandas_datareader.data as web

# %%
#从万得API获取阿里巴巴美股数据
'''
from WindPy import *
data1=w.wsd("BABA.N", "pre_close,open,high,low,close,volume", "2014-09-19", "2019-11-21", "TradingCalendar=NYSE",usedf=False)
dfBABAn=pd.DataFrame(data=data1.Data,index=data1.Fields,columns=data1.Times).T
'''
# Out:
# '\nfrom WindPy import *\ndata1=w.wsd("BABA.N", "pre_close,open,high,low,close,volume", "2014-09-19", "2019-11-21", "TradingCalendar=NYSE",usedf=False)\ndfBABAn=pd.DataFrame(data=data1.Data,index=data1.Fields,columns=data1.Times).T\n'

# %%
dfBABAn=pd.read_excel('BABAn.xlsx')
dfBABAn.rename({'Unnamed: 0':'Date'},axis=1,inplace=True)
dfBABAn.set_index('Date',inplace=True)

# %%
dfBABAn.tail()
# Out:
#             PRE_CLOSE    OPEN    HIGH     LOW   CLOSE      VOLUME
# Date
# 2019-11-15     182.80  184.00  185.60  183.71  185.49  11312540.0
# 2019-11-18     185.49  186.98  186.98  184.16  184.61  11830910.0
# 2019-11-19     184.61  186.31  186.71  183.87  185.25  13457360.0
# 2019-11-20     185.25  183.67  183.70  181.06  182.35  16689266.0
# 2019-11-21     182.35     NaN     NaN     NaN  182.35         NaN

# %%
#价格走势
dfBABAn['CLOSE'].plot(figsize=(8,5))
align_figures()
# Out:
# <img style="margin:0" align="left" src="...

# %%
#计算log return
dfBABAn['Return']=np.log(dfBABAn['CLOSE']/dfBABAn['CLOSE'].shift(1))
dfBABAn[['CLOSE','Return']].head()
# Out:
#             CLOSE    Return
# Date
# 2014-09-19  93.89       NaN
# 2014-09-22  89.89 -0.043537
# 2014-09-23  87.17 -0.030726
# 2014-09-24  90.57  0.038263
# 2014-09-25  88.92 -0.018386

# %%
dfBABAn.loc[dfBABAn.index[0]]['Return']=np.log(dfBABAn.loc[dfBABAn.index[0]]['CLOSE']
                                                /dfBABAn.loc[dfBABAn.index[0]]['PRE_CLOSE'])
dfBABAn[['CLOSE','Return']].head()
# Out:
#             CLOSE    Return
# Date
# 2014-09-19  93.89  0.322616
# 2014-09-22  89.89 -0.043537
# 2014-09-23  87.17 -0.030726
# 2014-09-24  90.57  0.038263
# 2014-09-25  88.92 -0.018386

# %%
dfBABAn[['CLOSE','Return']].plot(subplots=True,style='b',figsize=(8,5))
align_figures()
# Out:
# <img style="margin:0" align="left" src="...

# %%
#移动平均
dfBABAn['42d']=dfBABAn['CLOSE'].rolling(window=42).mean()
dfBABAn['252d']=dfBABAn['CLOSE'].rolling(window=252).mean()
dfBABAn.tail()
# Out:
#             PRE_CLOSE    OPEN    HIGH     LOW   CLOSE      VOLUME    Return  \
# Date
# 2019-11-15     182.80  184.00  185.60  183.71  185.49  11312540.0  0.014608
# 2019-11-18     185.49  186.98  186.98  184.16  184.61  11830910.0 -0.004755
# 2019-11-19     184.61  186.31  186.71  183.87  185.25  13457360.0  0.003461
# 2019-11-20     185.25  183.67  183.70  181.06  182.35  16689266.0 -0.015778
# 2019-11-21     182.35     NaN     NaN     NaN  182.35         NaN  0.000000
#
#                    42d        252d
# Date
# 2019-11-15  175.277381  168.850476
# 2019-11-18  175.376190  168.963135
# 2019-11-19  175.441429  169.086746
# 2019-11-20  175.569286  169.216984
# 2019-11-21  175.826429  169.361310

# %%
dfBABAn[['CLOSE','42d','252d']].plot(figsize=(8,5))
align_figures()
# Out:
# <img style="margin:0" align="left" src="...

# %%
#moving annual volatility
import math
dfBABAn['Mov_Vol']=dfBABAn['Return'].rolling(window=252).std()*math.sqrt(252)
dfBABAn.tail()
# Out:
#             PRE_CLOSE    OPEN    HIGH     LOW   CLOSE      VOLUME    Return  \
# Date
# 2019-11-15     182.80  184.00  185.60  183.71  185.49  11312540.0  0.014608
# 2019-11-18     185.49  186.98  186.98  184.16  184.61  11830910.0 -0.004755
# 2019-11-19     184.61  186.31  186.71  183.87  185.25  13457360.0  0.003461
# 2019-11-20     185.25  183.67  183.70  181.06  182.35  16689266.0 -0.015778
# 2019-11-21     182.35     NaN     NaN     NaN  182.35         NaN  0.000000
#
#                    42d        252d   Mov_Vol
# Date
# 2019-11-15  175.277381  168.850476  0.317501
# 2019-11-18  175.376190  168.963135  0.315383
# 2019-11-19  175.441429  169.086746  0.315067
# 2019-11-20  175.569286  169.216984  0.313983
# 2019-11-21  175.826429  169.361310  0.312994

# %%
dfBABAn[['CLOSE','Return','Mov_Vol']].plot(subplots=True,style='b',figsize=(8,7))
align_figures()
# Out:
# <img style="margin:0" align="left" src="...

# %%
#回归，wind接口坏了，只能拿现有数据
import datetime as dt
data=pd.DataFrame({'HIGH':
                  dfBABAn['HIGH'][dfBABAn.index>dt.datetime(2015,1,1)]})
data=data.join(pd.DataFrame({'LOW':
                            dfBABAn['LOW'][dfBABAn.index>dt.datetime(2015,1,1)]}))

# %%
data=data.fillna(method='ffill')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1232 entries, 2015-01-02 to 2019-11-21
# Data columns (total 2 columns):
# HIGH    1232 non-null float64
# LOW     1232 non-null float64
# dtypes: float64(2)
# memory usage: 68.9 KB

# %%
data.tail()
# Out:
#               HIGH     LOW
# Date
# 2019-11-15  185.60  183.71
# 2019-11-18  186.98  184.16
# 2019-11-19  186.71  183.87
# 2019-11-20  183.70  181.06
# 2019-11-21  183.70  181.06

# %%
data.plot(subplots=True,grid=True,style='b',figsize=(8,6))
align_figures()
# Out:
# <img style="margin:0" align="left" src="...

# %%
rets=np.log(data/data.shift(1))
rets.head()
# Out:
#                 HIGH       LOW
# Date
# 2015-01-02       NaN       NaN
# 2015-01-05 -0.016367 -0.025888
# 2015-01-06  0.008024  0.002100
# 2015-01-07  0.008534  0.018997
# 2015-01-08  0.005711  0.006350

# %%
rets.plot(subplots=True,grid=True,style='b',figsize=(8,6))
align_figures()
# Out:
# <img style="margin:0" align="left" src="...

# %%
import statsmodels.formula.api as smf
model=smf.ols(formula='HIGH~LOW',data=rets).fit()
model.params
# Out:
# Intercept    0.000151
# LOW          0.661693
# dtype: float64

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   HIGH   R-squared:                       0.543
# Model:                            OLS   Adj. R-squared:                  0.543
# Method:                 Least Squares   F-statistic:                     1460.
# Date:                Sat, 14 Dec 2019   Prob (F-statistic):          3.07e-211
# Time:                        17:49:45   Log-Likelihood:                 3622.3
# No. Observations:                1231   AIC:                            -7241.
# Df Residuals:                    1229   BIC:                            -7230.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0002      0.000      0.414      0.679      -0.001       0.001
# LOW            0.6617      0.017     38.216      0.000       0.628       0.696
# ==============================================================================
# Omnibus:                      162.639   Durbin-Watson:                   2.642
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1669.878
# Skew:                           0.159   Prob(JB):                         0.00
# Kurtosis:                       8.697   Cond. No.                         47.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
plt.plot(rets['HIGH'],rets['LOW'],'r.')
ax=plt.axis() #grab axis values
x=np.linspace(ax[0],ax[1]+0.01) #将x轴长度等分50份
plt.plot(x,model.params[0]+model.params[1]*x,'b',lw=2)
plt.grid=True
plt.axis('tight')
plt.xlabel('Low price returns')
plt.ylabel('High price returns')
align_figures()
# Out:
# <img style="margin:0" align="left" src="..."/>

# %%
rets.corr()
# Out:
#          HIGH      LOW
# HIGH  1.00000  0.73691
# LOW   0.73691  1.00000

# %%
#求rolling correlation
rets['HIGH'].rolling(252).corr(rets['LOW']).plot(grid=True,style='b')
align_figures()
# Out:
# <img style="margin:0" align="left" src="..."/>

# %%
#重新取样
rets_resam=rets.resample(rule='50d').mean()
rets_resam['HIGH'].fillna(method='ffill').plot()
align_figures()
# Out:
# <img style="margin:0" align="left" src="..."/>
